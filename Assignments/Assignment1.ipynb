# %% [markdown]
# # <font color="Blue">**Assignment:**
#
# Perform comprehensive EDA on a real-world dataset (e.g., Iris).
# <font color="Blue">*Generate a dataset and demonstrate various data pre-processing techniques for a given dataset using NumPy and Pandas.*
# - Reshaping the data
# - Filtering the data
# - Merging the data
# - Handling missing values
# - Feature Normalization (Min-Max normalization)
#
# The program should display intermediate results at each step along with brief
# comments explaining the purpose of each operation
